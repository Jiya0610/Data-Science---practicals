# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("shop_sales_data.csv")

# %%
df.head(5)
# Out:
#   Month   Product Category  Quantity_Sold  Unit_Price  Total_Sales
# 0   Jan      Rice  Grocery            120          50         6000
# 1   Feb      Rice  Grocery             90          50         4500
# 2   Mar     Sugar  Grocery            110          45         4950
# 3   Apr     Chips   Snacks            160          20         3200
# 4   May  Biscuits   Snacks            150          25         3750

# %%
min_r = df["Total_Sales"].min()
max_r = df["Total_Sales"].max()

# %%
min_r, max_r
# Out:
# (np.int64(3200), np.int64(14000))

# %%
range = max_r - min_r

# %%
range
# Out:
# np.int64(10800)
