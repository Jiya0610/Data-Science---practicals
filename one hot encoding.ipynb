# %%
import pandas as pd

# %%
df = pd.read_csv("tip.csv")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
# there are two methods

# %%
## method - 1 (get dummys)

# %%
df1 = pd.get_dummies(df['sex'])

# %%
df1
# Out:
#      Female   Male
# 0      True  False
# 1     False   True
# 2     False   True
# 3     False   True
# 4      True  False
# ..      ...    ...
# 239   False   True
# 240    True  False
# 241   False   True
# 242   False   True
# 243    True  False
#
# [244 rows x 2 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Female  244 non-null    bool
#  1   Male    244 non-null    bool
# dtypes: bool(2)
# memory usage: 620.0 bytes

# %%
# method - 2(sikit learn)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
var = OneHotEncoder(sparse_output=False)

# %%
arr = var.fit_transform(df[['sex']])

# %%
pd.DataFrame(arr,columns=["Female","Male"])
# Out:
#      Female  Male
# 0       1.0   0.0
# 1       0.0   1.0
# 2       0.0   1.0
# 3       0.0   1.0
# 4       1.0   0.0
# ..      ...   ...
# 239     0.0   1.0
# 240     1.0   0.0
# 241     0.0   1.0
# 242     0.0   1.0
# 243     1.0   0.0
#
# [244 rows x 2 columns]
