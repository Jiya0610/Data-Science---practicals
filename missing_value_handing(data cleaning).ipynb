# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("house_price_dataset.csv")

# %%
df.head()
# Out:
#   house_id  area_sqft  price     condition location
# 0     H001        NaN    NaN  Needs Repair    Rural
# 1     H002        NaN    NaN  Needs Repair  Unknown
# 2     H003        NaN    NaN           NaN    Urban
# 3     H004        NaN    NaN  Needs Repair    Rural
# 4     H005        NaN    NaN          Good    Urban

# %%
df.isnull().sum()
# Out:
# house_id       0
# area_sqft    654
# price        654
# condition    381
# location     181
# dtype: int64

# %%
df['area_sqft'].fillna(df['area_sqft'].mean(),inplace=True)
# Out:
# C:\Users\jiyam\AppData\Local\Temp\ipykernel_2816\3533482921.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['area_sqft'].fillna(df['area_sqft'].mean(),inplace=True)

# %%
df['price'].fillna(df['price'].mean(),inplace=True)
# Out:
# C:\Users\jiyam\AppData\Local\Temp\ipykernel_2816\3611970186.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['price'].fillna(df['price'].mean(),inplace=True)

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# house_id      0.0
# area_sqft     0.0
# price         0.0
# condition    38.1
# location     18.1
# dtype: float64

# %%
# for all null value
df.isnull().sum().sum()
# Out:
# np.int64(562)

# %%
# finding not null we use .notnull()

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
# when data has 50% null value then drop this column

# %%
df.drop(columns=['condition'],inplace=True)

# %%
df.head()
# Out:
#   house_id    area_sqft         price location
# 0     H001  2757.514451  1.398980e+07    Rural
# 1     H002  2757.514451  1.398980e+07  Unknown
# 2     H003  2757.514451  1.398980e+07    Urban
# 3     H004  2757.514451  1.398980e+07    Rural
# 4     H005  2757.514451  1.398980e+07    Urban

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# house_id     0
# area_sqft    0
# price        0
# location     0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df1 = pd.read_csv("Titanic-Dataset.csv")

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df1.select_dtypes(include="object").isnull().sum()
# Out:
# Name          0
# Sex           0
# Ticket        0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
for i in df1.select_dtypes(include="object").columns:
    df1[i].fillna(df1[i].mode()[0], inplace=True)
# Out:
# C:\Users\jiyam\AppData\Local\Temp\ipykernel_2816\1171911783.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1[i].fillna(df1[i].mode()[0], inplace=True)

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked
# 0      0         A/5 21171   7.2500  B96 B98        S
# 1      0          PC 17599  71.2833      C85        C
# 2      0  STON/O2. 3101282   7.9250  B96 B98        S
# 3      0            113803  53.1000     C123        S
# ...

# %%
data = pd.read_csv("house_price_dataset.csv")

# %%
data.head()
# Out:
#   house_id  area_sqft  price     condition location
# 0     H001        NaN    NaN  Needs Repair    Rural
# 1     H002        NaN    NaN  Needs Repair  Unknown
# 2     H003        NaN    NaN           NaN    Urban
# 3     H004        NaN    NaN  Needs Repair    Rural
# 4     H005        NaN    NaN          Good    Urban

# %%
data.isnull().sum()
# Out:
# house_id       0
# area_sqft    654
# price        654
# condition    381
# location     181
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
model = SimpleImputer(strategy="mean")

# %%
dataframe = model.fit_transform(data[['area_sqft','price']])

# %%
df2 = pd.DataFrame(dataframe,columns=data.select_dtypes(include="float").columns)

# %%
df2.head()
# Out:
#      area_sqft         price
# 0  2757.514451  1.398980e+07
# 1  2757.514451  1.398980e+07
# 2  2757.514451  1.398980e+07
# 3  2757.514451  1.398980e+07
# 4  2757.514451  1.398980e+07

# %%
df2.isnull().sum()
# Out:
# area_sqft    0
# price        0
# dtype: int64
